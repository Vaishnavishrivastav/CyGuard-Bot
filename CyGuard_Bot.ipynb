# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavishrivastav/CyGuard-Bot/blob/main/CyGuard_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

def cybersecurity_chatbot():
    print("🤖 CyberBot: Hello! I can help you stay safe online.")
    while True:
        user_input = input("You: ").lower()

        if re.search("password", user_input):
            print("CyberBot: Use strong passwords with upper/lowercase, numbers, and symbols. Avoid reusing them!")
        elif re.search("phishing", user_input):
            print("CyberBot: Never click unknown links or share OTPs. Always verify email senders.")
        elif re.search("malware", user_input):
            print("CyberBot: Keep antivirus updated and avoid downloading unverified files.")
        elif re.search("social engineering", user_input):
            print("CyberBot: Be cautious of people asking for personal info. Verify before sharing!")
        elif "bye" in user_input:
            print("CyberBot: Stay safe and secure online! 👋")
            break
        else:
            print("CyberBot: Sorry, I don’t know about that yet. Try asking about phishing or passwords.")

cybersecurity_chatbot()
# Out:
# 🤖 CyberBot: Hello! I can help you stay safe online.
# You: yes
# CyberBot: Sorry, I don’t know about that yet. Try asking about phishing or passwords.
# You: password
# CyberBot: Use strong passwords with upper/lowercase, numbers, and symbols. Avoid reusing them!
